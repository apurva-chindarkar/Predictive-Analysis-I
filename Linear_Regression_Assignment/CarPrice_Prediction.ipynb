# %%
# Supress Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing numpy and pandas
import numpy as np
import pandas as pd

# %%
# Importing CSV of CarPrice_Assignment
car_price = pd.read_csv("CarPrice_Assignment.csv")
car_price.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase   ...     enginesize  \
# 0  convertible        rwd          front       88.6   ...            130
# 1  convertible        rwd          front       88.6   ...            130
# 2    hatchback        rwd          front       94.5   ...            152
# 3        sedan        fwd          front       99.8   ...            109
# 4        sedan        4wd          front       99.4   ...            136
#
# ...

# %%
# Check the shape of dataset
car_price.shape
# Out:
# (205, 26)

# %%
# Check the info of dataset
car_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
# car_ID              205 non-null int64
# symboling           205 non-null int64
# CarName             205 non-null object
# fueltype            205 non-null object
# aspiration          205 non-null object
# doornumber          205 non-null object
# carbody             205 non-null object
# drivewheel          205 non-null object
# enginelocation      205 non-null object
# wheelbase           205 non-null float64
# carlength           205 non-null float64
# carwidth            205 non-null float64
# carheight           205 non-null float64
# curbweight          205 non-null int64
# enginetype          205 non-null object
# cylindernumber      205 non-null object
# enginesize          205 non-null int64
# fuelsystem          205 non-null object
# boreratio           205 non-null float64
# stroke              205 non-null float64
# compressionratio    205 non-null float64
# ...

# %%
# Getting addtional statistical info of dataset
car_price.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
# Check the Sum of Null values in the Columns of imported CSV, if any.
car_price.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
# Drop rows with the Duplicate rows, if any.
car_price = car_price.drop_duplicates(subset = None, keep = "first")
car_price.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase   ...     enginesize  \
# 0  convertible        rwd          front       88.6   ...            130
# 1  convertible        rwd          front       88.6   ...            130
# 2    hatchback        rwd          front       94.5   ...            152
# 3        sedan        fwd          front       99.8   ...            109
# 4        sedan        4wd          front       99.4   ...            136
#
# ...

# %%
# Creating a new column "Companyname" from "carname" by splitting the name and only retaining companyname of the car
car_price["Companyname"] = car_price["CarName"].str.split(' ').str[0]
car_price.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase     ...       fuelsystem  \
# 0  convertible        rwd          front       88.6     ...             mpfi
# 1  convertible        rwd          front       88.6     ...             mpfi
# 2    hatchback        rwd          front       94.5     ...             mpfi
# 3        sedan        fwd          front       99.8     ...             mpfi
# 4        sedan        4wd          front       99.4     ...             mpfi
#
# ...

# %%
# Dropping column "CarName" and "car_ID" since it is not required 
car_price.drop(['car_ID', 'CarName'], axis =1, inplace = True)
car_price.head()
# Out:
#    symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0          3      gas        std        two  convertible        rwd
# 1          3      gas        std        two  convertible        rwd
# 2          1      gas        std        two    hatchback        rwd
# 3          2      gas        std       four        sedan        fwd
# 4          2      gas        std       four        sedan        4wd
#
#   enginelocation  wheelbase  carlength  carwidth     ...       fuelsystem  \
# 0          front       88.6      168.8      64.1     ...             mpfi
# 1          front       88.6      168.8      64.1     ...             mpfi
# 2          front       94.5      171.2      65.5     ...             mpfi
# 3          front       99.8      176.6      66.2     ...             mpfi
# 4          front       99.4      176.6      66.4     ...             mpfi
#
#    boreratio stroke compressionratio  horsepower peakrpm  citympg  highwaympg  \
# ...

# %%
# Correcting spelling errors and getting all names in same format
car_price.Companyname = car_price["Companyname"].str.lower()
car_price["Companyname"] = car_price["Companyname"].str.replace('maxda','mazda')
car_price["Companyname"] = car_price["Companyname"].str.replace('porcshce','porsche')
car_price["Companyname"] = car_price["Companyname"].str.replace('toyouta','toyota')
car_price["Companyname"] = car_price["Companyname"].str.replace('vokswagen','volkswagen')
car_price["Companyname"] = car_price["Companyname"].str.replace('vw','volkswagen')
car_price.head()
# Out:
#    symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0          3      gas        std        two  convertible        rwd
# 1          3      gas        std        two  convertible        rwd
# 2          1      gas        std        two    hatchback        rwd
# 3          2      gas        std       four        sedan        fwd
# 4          2      gas        std       four        sedan        4wd
#
#   enginelocation  wheelbase  carlength  carwidth     ...       fuelsystem  \
# 0          front       88.6      168.8      64.1     ...             mpfi
# 1          front       88.6      168.8      64.1     ...             mpfi
# 2          front       94.5      171.2      65.5     ...             mpfi
# 3          front       99.8      176.6      66.2     ...             mpfi
# 4          front       99.4      176.6      66.4     ...             mpfi
#
#    boreratio stroke compressionratio  horsepower peakrpm  citympg  highwaympg  \
# ...

# %% [markdown]
# None of the columns have null values and none of the rows have duplicate values.
# Car name is in required format (Comapanyname)
# Since the data is cleaned, we can proceed with further analysis.

# %%
# Visualising the data
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Visualiing all the numeric variables using "pair-plots" 
sns.set(font_scale=2)
sns.pairplot(car_price)
plt.show()

# %%
# Let's check the correlations to see which variables are highly correlated
plt.figure(figsize = (40, 25))
sns.heatmap(car_price.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %%
# Visualising categorical variables using box-plots
plt.figure(figsize=(20, 12))
plt.subplot(2,2,1)
sns.boxplot(x = 'fueltype', y = 'price', data = car_price)
plt.subplot(2,2,2)
sns.boxplot(x = 'aspiration', y = 'price', data = car_price)
plt.subplot(2,2,3)
sns.boxplot(x = 'doornumber', y = 'price', data = car_price)
plt.subplot(2,2,4)
sns.boxplot(x = 'enginelocation', y = 'price', data = car_price)

# %%
# Visualising "enginetype" vs. "price" using box-plot
plt.figure(figsize = (20, 10))
sns.boxplot(x = 'enginetype', y = 'price', data = car_price)
plt.show()

# %%
# Visualising "fuelsystem" vs. "price" using box-plot
plt.figure(figsize = (20, 10))
sns.boxplot(x = 'fuelsystem', y = 'price', data = car_price)
plt.show()

# %%
# Visualising "carbody" vs. "price" using box-plot
plt.figure(figsize = (20, 10))
sns.boxplot(x = 'carbody', y = 'price', data = car_price)
plt.show()

# %%
# Visualising "drivewheel" vs. "price" using box-plot
plt.figure(figsize = (20, 10))
sns.boxplot(x = 'drivewheel', y = 'price', data = car_price)
plt.show()

# %%
# Visualising "Companyname" vs. "price" using box-plot
plt.figure(figsize = (40, 20))
sns.boxplot(x = 'Companyname', y = 'price', data = car_price)
plt.show()

# %% [markdown]
# After getting box-plots for all the categorical variables, we can observe some relationship between each of these variables and price. Since none of the categorical variables plotted above are ordinal, all the categorical variables with two levels need to be converted into "0" & "1" and variables with more than two states/levels will be processed by creating dummy variables.

# %%
# Binary mapping for categorical variables with two levels
car_price['fueltype'] = car_price['fueltype'].map({'gas': 1, 'diesel': 0})
car_price['aspiration'] = car_price['aspiration'].map({'std': 1, 'turbo': 0})
car_price['doornumber'] = car_price['doornumber'].map({'two': 1, 'four': 0})
car_price['enginelocation'] = car_price['enginelocation'].map({'front': 1, 'rear': 0})
car_price.head()
# Out:
#    symboling  fueltype  aspiration  doornumber      carbody drivewheel  \
# 0          3         1           1           1  convertible        rwd
# 1          3         1           1           1  convertible        rwd
# 2          1         1           1           1    hatchback        rwd
# 3          2         1           1           0        sedan        fwd
# 4          2         1           1           0        sedan        4wd
#
#    enginelocation  wheelbase  carlength  carwidth     ...       fuelsystem  \
# 0               1       88.6      168.8      64.1     ...             mpfi
# 1               1       88.6      168.8      64.1     ...             mpfi
# 2               1       94.5      171.2      65.5     ...             mpfi
# 3               1       99.8      176.6      66.2     ...             mpfi
# 4               1       99.4      176.6      66.4     ...             mpfi
#
#    boreratio stroke compressionratio  horsepower peakrpm  citympg  highwaympg  \
# ...

# %%
#"cylindernumber" converted from strings to int by mapping words with numerical values
car_price['cylindernumber'] = car_price['cylindernumber'].map({"two": 2, "three": 3, "four": 4, "five": 5, "six": 6,"eight": 8, "twelve": 12})
car_price.head()
# Out:
#    symboling  fueltype  aspiration  doornumber      carbody drivewheel  \
# 0          3         1           1           1  convertible        rwd
# 1          3         1           1           1  convertible        rwd
# 2          1         1           1           1    hatchback        rwd
# 3          2         1           1           0        sedan        fwd
# 4          2         1           1           0        sedan        4wd
#
#    enginelocation  wheelbase  carlength  carwidth     ...       fuelsystem  \
# 0               1       88.6      168.8      64.1     ...             mpfi
# 1               1       88.6      168.8      64.1     ...             mpfi
# 2               1       94.5      171.2      65.5     ...             mpfi
# 3               1       99.8      176.6      66.2     ...             mpfi
# 4               1       99.4      176.6      66.4     ...             mpfi
#
#    boreratio stroke  compressionratio  horsepower peakrpm  citympg  \
# ...

# %%
# To confirm the datatype of categorical variables converted to int
car_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205 entries, 0 to 204
# Data columns (total 25 columns):
# symboling           205 non-null int64
# fueltype            205 non-null int64
# aspiration          205 non-null int64
# doornumber          205 non-null int64
# carbody             205 non-null object
# drivewheel          205 non-null object
# enginelocation      205 non-null int64
# wheelbase           205 non-null float64
# carlength           205 non-null float64
# carwidth            205 non-null float64
# carheight           205 non-null float64
# curbweight          205 non-null int64
# enginetype          205 non-null object
# cylindernumber      205 non-null int64
# enginesize          205 non-null int64
# fuelsystem          205 non-null object
# boreratio           205 non-null float64
# stroke              205 non-null float64
# compressionratio    205 non-null float64
# horsepower          205 non-null int64
# peakrpm             205 non-null int64
# ...

# %% [markdown]
# Dummy Variables will be created for catergorical variables with more than two levels.

# %%
# While creating dummy variables, first dummy variable and original varaible column will be dropped. 
car_df = pd.get_dummies((car_price), drop_first = True)
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205 entries, 0 to 204
# Data columns (total 60 columns):
# symboling                 205 non-null int64
# fueltype                  205 non-null int64
# aspiration                205 non-null int64
# doornumber                205 non-null int64
# enginelocation            205 non-null int64
# wheelbase                 205 non-null float64
# carlength                 205 non-null float64
# carwidth                  205 non-null float64
# carheight                 205 non-null float64
# curbweight                205 non-null int64
# cylindernumber            205 non-null int64
# enginesize                205 non-null int64
# boreratio                 205 non-null float64
# stroke                    205 non-null float64
# compressionratio          205 non-null float64
# horsepower                205 non-null int64
# peakrpm                   205 non-null int64
# citympg                   205 non-null int64
# ...

# %% [markdown]
# Splitting the data into TRAINING AND TESTING sets...

# %%
from sklearn.model_selection import train_test_split

# We specify this so that the train and test data set always have the same rows, respectively

df_train, df_test = train_test_split(car_df, train_size = 0.7, test_size = 0.3, random_state = 100)

# %% [markdown]
# Rescaling the features using MinMax scaling:

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
# Apply scaler() to all the columns of numeric variables
num_vars = ['symboling', 'wheelbase', 'carlength', 'carwidth', 'carheight', 
            'curbweight', 'cylindernumber', 'enginesize', 'boreratio', 'stroke',
            'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price']

df_train[num_vars] = scaler.fit_transform(df_train[num_vars])

df_train.head()
# Out:
#      symboling  fueltype  aspiration  doornumber  enginelocation  wheelbase  \
# 122        0.6         1           1           0               1   0.244828
# 125        1.0         1           1           1               1   0.272414
# 166        0.6         1           1           1               1   0.272414
# 1          1.0         1           1           1               1   0.068966
# 199        0.2         1           0           0               1   0.610345
#
#      carlength  carwidth  carheight  curbweight        ...          \
# 122   0.426016  0.291667   0.265487    0.272692        ...
# 125   0.452033  0.666667   0.212389    0.500388        ...
# 166   0.448780  0.308333   0.424779    0.314973        ...
# 1     0.450407  0.316667   0.088496    0.411171        ...
# 199   0.775610  0.575000   0.858407    0.647401        ...
#
#      Companyname_nissan  Companyname_peugeot  Companyname_plymouth  \
# 122                   0                    0                     1
# ...

# %% [markdown]
# Dividing data into X and Y sets for building the model and using the **LinearRegression function from SciKit Learn** for model building

# %%
y_train = df_train.pop('price')
X_train = df_train

# %%
# Importing RFE and LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# %%
# Running RFE with the output number of the variable equal to 20
lm = LinearRegression()
lm.fit(X_train, y_train)

rfe = RFE(lm, 20)             # running RFE
rfe = rfe.fit(X_train, y_train)

# %%
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('symboling', False, 32),
#  ('fueltype', True, 1),
#  ('aspiration', False, 10),
#  ('doornumber', False, 31),
#  ('enginelocation', True, 1),
#  ('wheelbase', True, 1),
#  ('carlength', True, 1),
#  ('carwidth', True, 1),
#  ('carheight', False, 13),
#  ('curbweight', True, 1),
#  ('cylindernumber', True, 1),
#  ('enginesize', True, 1),
#  ('boreratio', True, 1),
#  ('stroke', True, 1),
#  ('compressionratio', True, 1),
#  ('horsepower', False, 8),
#  ('peakrpm', True, 1),
#  ('citympg', True, 1),
#  ('highwaympg', False, 20),
#  ('carbody_hardtop', False, 5),
#  ('carbody_hatchback', False, 2),
#  ('carbody_sedan', False, 4),
#  ('carbody_wagon', False, 3),
#  ('drivewheel_fwd', False, 30),
#  ('drivewheel_rwd', False, 35),
#  ('enginetype_dohcv', False, 9),
#  ('enginetype_l', True, 1),
#  ('enginetype_ohc', False, 16),
#  ('enginetype_ohcf', False, 7),
#  ('enginetype_ohcv', False, 37),
#  ('enginetype_rotor', True, 1),
#  ('fuelsystem_2bbl', False, 28),
# ...

# %%
col = X_train.columns[rfe.support_]
col
# Out:
# Index(['fueltype', 'enginelocation', 'wheelbase', 'carlength', 'carwidth',
#        'curbweight', 'cylindernumber', 'enginesize', 'boreratio', 'stroke',
#        'compressionratio', 'peakrpm', 'citympg', 'enginetype_l',
#        'enginetype_rotor', 'fuelsystem_idi', 'Companyname_bmw',
#        'Companyname_peugeot', 'Companyname_porsche', 'Companyname_saab'],
#       dtype='object')

# %%
X_train.columns[~rfe.support_]
# Out:
# Index(['symboling', 'aspiration', 'doornumber', 'carheight', 'horsepower',
#        'highwaympg', 'carbody_hardtop', 'carbody_hatchback', 'carbody_sedan',
#        'carbody_wagon', 'drivewheel_fwd', 'drivewheel_rwd', 'enginetype_dohcv',
#        'enginetype_ohc', 'enginetype_ohcf', 'enginetype_ohcv',
#        'fuelsystem_2bbl', 'fuelsystem_4bbl', 'fuelsystem_mfi',
#        'fuelsystem_mpfi', 'fuelsystem_spdi', 'fuelsystem_spfi',
#        'Companyname_audi', 'Companyname_buick', 'Companyname_chevrolet',
#        'Companyname_dodge', 'Companyname_honda', 'Companyname_isuzu',
#        'Companyname_jaguar', 'Companyname_mazda', 'Companyname_mercury',
#        'Companyname_mitsubishi', 'Companyname_nissan', 'Companyname_plymouth',
#        'Companyname_renault', 'Companyname_subaru', 'Companyname_toyota',
#        'Companyname_volkswagen', 'Companyname_volvo'],
#       dtype='object')

# %%
# Creating DF of the 20 selected features and 'price' so that heatmap can be plotted to check correlations
h_plot = car_df[['price', 'fueltype', 'enginelocation', 'wheelbase', 'carlength', 'carwidth', 'curbweight', 'cylindernumber', 'enginesize', 'boreratio', 'stroke', 'compressionratio', 'peakrpm', 'citympg', 'enginetype_l', 'enginetype_rotor', 'fuelsystem_idi', 'Companyname_bmw', 'Companyname_peugeot', 'Companyname_porsche', 'Companyname_saab']]
h_plot
# Out:
#          price  fueltype  enginelocation  wheelbase  carlength  carwidth  \
# 0    13495.000         1               1       88.6      168.8      64.1
# 1    16500.000         1               1       88.6      168.8      64.1
# 2    16500.000         1               1       94.5      171.2      65.5
# 3    13950.000         1               1       99.8      176.6      66.2
# 4    17450.000         1               1       99.4      176.6      66.4
# 5    15250.000         1               1       99.8      177.3      66.3
# 6    17710.000         1               1      105.8      192.7      71.4
# 7    18920.000         1               1      105.8      192.7      71.4
# 8    23875.000         1               1      105.8      192.7      71.4
# 9    17859.167         1               1       99.5      178.2      67.9
# 10   16430.000         1               1      101.2      176.8      64.8
# 11   16925.000         1               1      101.2      176.8      64.8
# ...

# %%
# Let's check the correlations to see which variables are highly correlated (20 selected features and price)

plt.figure(figsize = (40, 20))
sns.heatmap(h_plot.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %% [markdown]
# Model building using Statsmodel for the detailed statistics

# %%
# Creating X_test dataframe with RFE selected variables
X_train_rfe = X_train[col]

# %%
# Adding a constant variable 
import statsmodels.api as sm  
X_train_rfe = sm.add_constant(X_train_rfe)

# %%
# Running the linear model
lm = sm.OLS(y_train,X_train_rfe).fit()

# %%
# Summary of linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.942
# Model:                            OLS   Adj. R-squared:                  0.933
# Method:                 Least Squares   F-statistic:                     104.4
# Date:                Mon, 29 Apr 2019   Prob (F-statistic):           2.06e-66
# Time:                        17:20:02   Log-Likelihood:                 220.05
# No. Observations:                 143   AIC:                            -400.1
# Df Residuals:                     123   BIC:                            -340.8
# Df Model:                          19
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.3300      0.077      4.275      0.000       0.177       0.483
# ...

# %%
# Dropping 'const'
X_train_1 = X_train_rfe.drop(["const"], axis = 1)

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_1
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                Features     VIF
# 0              fueltype  387.47
# 15       fuelsystem_idi  119.17
# 10     compressionratio   83.34
# 7            enginesize   40.24
# 5            curbweight   21.52
# 6        cylindernumber   21.07
# 3             carlength   12.70
# 17  Companyname_peugeot   10.62
# 13         enginetype_l   10.06
# 12              citympg    8.39
# 4              carwidth    8.28
# 8             boreratio    7.86
# 2             wheelbase    7.63
# 9                stroke    3.86
# 18  Companyname_porsche    2.95
# 14     enginetype_rotor    2.65
# 11              peakrpm    2.07
# 1        enginelocation    2.02
# 16      Companyname_bmw    1.27
# 19     Companyname_saab    1.22

# %% [markdown]
# Since 'fueltype' is insignificant (high p-value) and VIF for the same is high in presence of other variables, it will be dropped and model will be rebuilt without it.

# %%
# Dropping 'fueltype'
X_train_1 = X_train_rfe.drop(["fueltype"], axis = 1)

# %%
# Rebuilding the model
# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_1)

# %%
# Running the linear model
lm = sm.OLS(y_train,X_train_lm).fit()

# %%
# Summary of linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.942
# Model:                            OLS   Adj. R-squared:                  0.933
# Method:                 Least Squares   F-statistic:                     104.4
# Date:                Mon, 29 Apr 2019   Prob (F-statistic):           2.06e-66
# Time:                        17:20:02   Log-Likelihood:                 220.05
# No. Observations:                 143   AIC:                            -400.1
# Df Residuals:                     123   BIC:                            -340.8
# Df Model:                          19
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.3240      0.097      3.351      0.001       0.133       0.515
# ...

# %%
# Dropping 'const'
X_train_2 = X_train_1.drop(["const"], axis = 1)

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_2
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                Features     VIF
# 0        enginelocation  184.68
# 9      compressionratio  134.95
# 6            enginesize  127.94
# 4            curbweight   98.54
# 5        cylindernumber   95.22
# 14       fuelsystem_idi   92.34
# 2             carlength   87.69
# 3              carwidth   53.96
# 7             boreratio   45.61
# 8                stroke   42.68
# 1             wheelbase   37.97
# 11              citympg   29.45
# 16  Companyname_peugeot   11.20
# 12         enginetype_l   10.70
# 10              peakrpm    9.54
# 17  Companyname_porsche    2.79
# 13     enginetype_rotor    2.50
# 15      Companyname_bmw    1.32
# 18     Companyname_saab    1.24

# %% [markdown]
# Since 'compressionratio' has high VIF and it's correlation with 'price' is really low, it will be dropped and model will be rebuilt without it.

# %%
# Dropping 'compressionratio'
X_train_2 = X_train_1.drop(["compressionratio"], axis = 1)

# %%
# Rebuilding the model
# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_2)

# %%
# Running the linear model
lm = sm.OLS(y_train,X_train_lm).fit()

# %%
# Summary of linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.940
# Model:                            OLS   Adj. R-squared:                  0.931
# Method:                 Least Squares   F-statistic:                     107.7
# Date:                Mon, 29 Apr 2019   Prob (F-statistic):           1.18e-66
# Time:                        17:20:02   Log-Likelihood:                 217.94
# No. Observations:                 143   AIC:                            -397.9
# Df Residuals:                     124   BIC:                            -341.6
# Df Model:                          18
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.3499      0.097      3.616      0.000       0.158       0.541
# ...

# %%
# Dropping 'const'
X_train_3 = X_train_2.drop(["const"], axis = 1)

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_3
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                Features     VIF
# 0        enginelocation  183.70
# 6            enginesize  126.79
# 4            curbweight   94.15
# 5        cylindernumber   92.05
# 2             carlength   78.36
# 3              carwidth   51.81
# 7             boreratio   45.43
# 8                stroke   39.99
# 1             wheelbase   37.61
# 10              citympg   22.96
# 15  Companyname_peugeot   11.19
# 11         enginetype_l   10.64
# 9               peakrpm    9.34
# 13       fuelsystem_idi    2.91
# 16  Companyname_porsche    2.53
# 12     enginetype_rotor    1.73
# 14      Companyname_bmw    1.28
# 17     Companyname_saab    1.21

# %% [markdown]
# Since 'citympg' is insignificant (high p-value) in presence of other variables, it will be dropped and model will be rebuilt without it.

# %%
# Dropping 'citympg'
X_train_3 = X_train_2.drop(["citympg"], axis = 1)

# %%
# Rebuilding the model
# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_3)

# %%
# Running the linear model
lm = sm.OLS(y_train,X_train_lm).fit()

# %%
# Summary of linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.940
# Model:                            OLS   Adj. R-squared:                  0.932
# Method:                 Least Squares   F-statistic:                     114.9
# Date:                Mon, 29 Apr 2019   Prob (F-statistic):           1.10e-67
# Time:                        17:20:03   Log-Likelihood:                 217.92
# No. Observations:                 143   AIC:                            -399.8
# Df Residuals:                     125   BIC:                            -346.5
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.3580      0.086      4.158      0.000       0.188       0.528
# ...

# %%
# Dropping 'const'
X_train_4 = X_train_3.drop(["const"], axis = 1)

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_4
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                Features     VIF
# 0        enginelocation  126.75
# 6            enginesize  126.54
# 5        cylindernumber   91.40
# 2             carlength   78.26
# 4            curbweight   70.43
# 3              carwidth   50.00
# 7             boreratio   45.42
# 8                stroke   39.91
# 1             wheelbase   36.41
# 14  Companyname_peugeot   10.66
# 10         enginetype_l    9.88
# 9               peakrpm    9.30
# 15  Companyname_porsche    2.43
# 12       fuelsystem_idi    1.97
# 11     enginetype_rotor    1.65
# 13      Companyname_bmw    1.25
# 16     Companyname_saab    1.21

# %% [markdown]
# Since 'enginelocation' has high VIF, it will be dropped and model will be rebuilt without it.

# %%
# Dropping 'enginelocation' 
X_train_4 = X_train_3.drop(["enginelocation"], axis = 1)

# %%
# Rebuilding the model
# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_4)

# %%
# Running the linear model
lm = sm.OLS(y_train,X_train_lm).fit()

# %%
# Summary of linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.933
# Model:                            OLS   Adj. R-squared:                  0.925
# Method:                 Least Squares   F-statistic:                     110.2
# Date:                Mon, 29 Apr 2019   Prob (F-statistic):           6.15e-66
# Time:                        17:20:03   Log-Likelihood:                 210.55
# No. Observations:                 143   AIC:                            -387.1
# Df Residuals:                     126   BIC:                            -336.7
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.1237      0.061      2.031      0.044       0.003       0.244
# ...

# %%
# Dropping 'const'
X_train_5 = X_train_4.drop(["const"], axis = 1)

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_5
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                Features    VIF
# 1             carlength  77.19
# 3            curbweight  66.93
# 2              carwidth  50.00
# 5            enginesize  45.97
# 0             wheelbase  36.29
# 4        cylindernumber  25.62
# 6             boreratio  13.50
# 7                stroke  12.05
# 13  Companyname_peugeot  10.40
# 9          enginetype_l   9.62
# 8               peakrpm   9.21
# 11       fuelsystem_idi   1.95
# 10     enginetype_rotor   1.63
# 14  Companyname_porsche   1.61
# 12      Companyname_bmw   1.25
# 15     Companyname_saab   1.20

# %% [markdown]
# Since 'carlength' is insignificant (high p-value) and has high VIF, it will be dropped and model will be rebuilt without it.

# %%
# Dropping 'carlength' 
X_train_5 = X_train_4.drop(["carlength"], axis = 1)

# %%
# Rebuilding the model
# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_5)

# %%
# Running the linear model
lm = sm.OLS(y_train,X_train_lm).fit()

# %%
# Summary of linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.924
# Method:                 Least Squares   F-statistic:                     116.2
# Date:                Mon, 29 Apr 2019   Prob (F-statistic):           1.73e-66
# Time:                        17:20:03   Log-Likelihood:                 209.26
# No. Observations:                 143   AIC:                            -386.5
# Df Residuals:                     127   BIC:                            -339.1
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.1165      0.061      1.909      0.059      -0.004       0.237
# ...

# %%
# Dropping 'const'
X_train_6 = X_train_5.drop(["const"], axis = 1)

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_6
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                Features    VIF
# 2            curbweight  56.56
# 1              carwidth  48.56
# 4            enginesize  43.72
# 0             wheelbase  27.35
# 3        cylindernumber  25.00
# 6                stroke  11.59
# 5             boreratio  10.63
# 12  Companyname_peugeot  10.33
# 8          enginetype_l   9.42
# 7               peakrpm   9.21
# 10       fuelsystem_idi   1.91
# 9      enginetype_rotor   1.62
# 13  Companyname_porsche   1.53
# 11      Companyname_bmw   1.24
# 14     Companyname_saab   1.12

# %% [markdown]
# 'wheelbase' will be dropped due to high p-value and model will be rebuilt without it.

# %%
# Dropping 'wheelbase' 
X_train_6 = X_train_5.drop(["wheelbase"], axis = 1)

# %%
# Rebuilding the model
# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_6)

# %%
# Running the linear model
lm = sm.OLS(y_train,X_train_lm).fit()

# %%
# Summary of linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.925
# Method:                 Least Squares   F-statistic:                     125.4
# Date:                Mon, 29 Apr 2019   Prob (F-statistic):           1.57e-67
# Time:                        17:20:03   Log-Likelihood:                 209.22
# No. Observations:                 143   AIC:                            -388.4
# Df Residuals:                     128   BIC:                            -344.0
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.1177      0.061      1.942      0.054      -0.002       0.238
# ...

# %%
# Dropping 'const'
X_train_7 = X_train_6.drop(["const"], axis = 1)

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_7
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                Features    VIF
# 1            curbweight  50.44
# 3            enginesize  42.36
# 0              carwidth  36.97
# 2        cylindernumber  24.95
# 5                stroke  11.42
# 4             boreratio  10.59
# 11  Companyname_peugeot  10.27
# 7          enginetype_l   9.40
# 6               peakrpm   9.19
# 9        fuelsystem_idi   1.90
# 8      enginetype_rotor   1.54
# 12  Companyname_porsche   1.33
# 10      Companyname_bmw   1.16
# 13     Companyname_saab   1.11

# %% [markdown]
# Since 'curbweight' has high VIF, it will be dropped and model will be rebuilt without it.

# %%
# Dropping 'curbweight' 
X_train_7 = X_train_6.drop(["curbweight"], axis = 1)

# %%
# Rebuilding the model
# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_7)

# %%
# Running the linear model
lm = sm.OLS(y_train,X_train_lm).fit()

# %%
# Summary of linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.926
# Model:                            OLS   Adj. R-squared:                  0.918
# Method:                 Least Squares   F-statistic:                     123.8
# Date:                Mon, 29 Apr 2019   Prob (F-statistic):           3.76e-66
# Time:                        17:20:04   Log-Likelihood:                 202.91
# No. Observations:                 143   AIC:                            -377.8
# Df Residuals:                     129   BIC:                            -336.3
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.1655      0.061      2.696      0.008       0.044       0.287
# ...

# %%
# Dropping 'const'
X_train_8 = X_train_7.drop(["const"], axis = 1)

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_8
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                Features    VIF
# 0              carwidth  25.56
# 2            enginesize  24.54
# 1        cylindernumber  24.01
# 4                stroke  11.33
# 3             boreratio  10.43
# 10  Companyname_peugeot  10.15
# 6          enginetype_l   9.40
# 5               peakrpm   9.13
# 8        fuelsystem_idi   1.87
# 7      enginetype_rotor   1.49
# 11  Companyname_porsche   1.25
# 9       Companyname_bmw   1.16
# 12     Companyname_saab   1.09

# %% [markdown]
# Since 'cylindernumber' has VIF > 10 and and it has high correlation with price and other features, it will be dropped and model will be rebuilt without it.

# %%
# Dropping 'cylindernumber' 
X_train_8 = X_train_7.drop(["cylindernumber"], axis = 1)

# %%
# Rebuilding the model
# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_8)

# %%
# Running the linear model
lm = sm.OLS(y_train,X_train_lm).fit()

# %%
# Summary of linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.905
# Model:                            OLS   Adj. R-squared:                  0.897
# Method:                 Least Squares   F-statistic:                     103.5
# Date:                Mon, 29 Apr 2019   Prob (F-statistic):           2.18e-60
# Time:                        17:20:04   Log-Likelihood:                 185.46
# No. Observations:                 143   AIC:                            -344.9
# Df Residuals:                     130   BIC:                            -306.4
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  -0.1483      0.036     -4.152      0.000      -0.219      -0.078
# ...

# %%
# Dropping 'const'
X_train_9 = X_train_8.drop(["const"], axis = 1)

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_9
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                Features    VIF
# 0              carwidth  24.28
# 1            enginesize  11.30
# 3                stroke  11.20
# 9   Companyname_peugeot   9.91
# 2             boreratio   9.89
# 5          enginetype_l   9.33
# 4               peakrpm   7.03
# 7        fuelsystem_idi   1.87
# 6      enginetype_rotor   1.24
# 10  Companyname_porsche   1.24
# 8       Companyname_bmw   1.15
# 11     Companyname_saab   1.08

# %% [markdown]
# Since 'stroke' has VIF > 10 and and it has low correlation with price and other features, it will be dropped and model will be rebuilt without it.

# %%
# Dropping 'stroke' 
X_train_9 = X_train_8.drop(["stroke"], axis = 1)

# %%
# Rebuilding the model
# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_9)

# %%
# Running the linear model
lm = sm.OLS(y_train,X_train_lm).fit()

# %%
# Summary of linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.900
# Model:                            OLS   Adj. R-squared:                  0.891
# Method:                 Least Squares   F-statistic:                     106.8
# Date:                Mon, 29 Apr 2019   Prob (F-statistic):           8.52e-60
# Time:                        17:20:04   Log-Likelihood:                 181.33
# No. Observations:                 143   AIC:                            -338.7
# Df Residuals:                     131   BIC:                            -303.1
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  -0.2075      0.029     -7.057      0.000      -0.266      -0.149
# ...

# %%
# Dropping 'const'
X_train_10 = X_train_9.drop(["const"], axis = 1)

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_10
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                Features    VIF
# 0              carwidth  22.95
# 1            enginesize  11.14
# 2             boreratio   9.83
# 8   Companyname_peugeot   9.73
# 4          enginetype_l   9.25
# 3               peakrpm   4.50
# 6        fuelsystem_idi   1.60
# 5      enginetype_rotor   1.22
# 7       Companyname_bmw   1.15
# 9   Companyname_porsche   1.12
# 10     Companyname_saab   1.07

# %% [markdown]
# Since 'boreratio' is insignificant (high p-value) in presence of other variables, it will be dropped and model will be rebuilt without it.

# %%
# Dropping 'boreratio' 
X_train_10 = X_train_9.drop(["boreratio"], axis = 1)

# %%
# Rebuilding the model
# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_10)

# %%
# Running the linear model
lm = sm.OLS(y_train,X_train_lm).fit()

# %%
# Summary of linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.899
# Model:                            OLS   Adj. R-squared:                  0.891
# Method:                 Least Squares   F-statistic:                     117.4
# Date:                Mon, 29 Apr 2019   Prob (F-statistic):           1.21e-60
# Time:                        17:20:04   Log-Likelihood:                 180.83
# No. Observations:                 143   AIC:                            -339.7
# Df Residuals:                     132   BIC:                            -307.1
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  -0.2233      0.024     -9.160      0.000      -0.272      -0.175
# ...

# %%
# Dropping 'const'
X_train_11 = X_train_10.drop(["const"], axis = 1)

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_11
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#               Features    VIF
# 0             carwidth  18.57
# 1           enginesize  10.87
# 7  Companyname_peugeot   9.73
# 3         enginetype_l   9.21
# 2              peakrpm   4.42
# 5       fuelsystem_idi   1.60
# 4     enginetype_rotor   1.21
# 6      Companyname_bmw   1.14
# 8  Companyname_porsche   1.08
# 9     Companyname_saab   1.04

# %% [markdown]
# Since 'Companyname_saab' is insignificant (p-value > 0.05) in presence of other variables, it will be dropped and model will be rebuilt without it.

# %%
# Dropping 'Companyname_saab'
X_train_11 = X_train_10.drop(["Companyname_saab"], axis = 1)

# %%
# Rebuilding the model
# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_11)

# %%
# Running the linear model
lm = sm.OLS(y_train,X_train_lm).fit()

# %%
# Summary of linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.890
# Method:                 Least Squares   F-statistic:                     128.3
# Date:                Mon, 29 Apr 2019   Prob (F-statistic):           4.31e-61
# Time:                        17:20:04   Log-Likelihood:                 179.27
# No. Observations:                 143   AIC:                            -338.5
# Df Residuals:                     133   BIC:                            -308.9
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  -0.2254      0.025     -9.190      0.000      -0.274      -0.177
# ...

# %%
# Dropping 'const'
X_train_12 = X_train_11.drop(["const"], axis = 1)

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_12
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#               Features    VIF
# 0             carwidth  18.37
# 1           enginesize  10.80
# 7  Companyname_peugeot   9.73
# 3         enginetype_l   9.21
# 2              peakrpm   4.42
# 5       fuelsystem_idi   1.60
# 4     enginetype_rotor   1.21
# 6      Companyname_bmw   1.14
# 8  Companyname_porsche   1.08

# %% [markdown]
# Since 'carwidth' has VIF > 10, it will be dropped and model will be rebuilt without it.

# %%
# Dropping 'carwidth'
X_train_12 = X_train_11.drop(["carwidth"], axis = 1)

# %%
# Rebuilding the model
# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_12)

# %%
# Running the linear model
lm = sm.OLS(y_train,X_train_lm).fit()

# %%
# Summary of linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.860
# Model:                            OLS   Adj. R-squared:                  0.852
# Method:                 Least Squares   F-statistic:                     103.3
# Date:                Mon, 29 Apr 2019   Prob (F-statistic):           1.72e-53
# Time:                        17:20:05   Log-Likelihood:                 157.77
# No. Observations:                 143   AIC:                            -297.5
# Df Residuals:                     134   BIC:                            -270.9
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  -0.1504      0.025     -5.923      0.000      -0.201      -0.100
# ...

# %%
# Dropping 'const'
X_train_13 = X_train_12.drop(["const"], axis = 1)

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_13
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#               Features   VIF
# 6  Companyname_peugeot  9.31
# 2         enginetype_l  9.12
# 0           enginesize  2.81
# 1              peakrpm  2.47
# 4       fuelsystem_idi  1.37
# 3     enginetype_rotor  1.17
# 5      Companyname_bmw  1.13
# 7  Companyname_porsche  1.08

# %% [markdown]
# Since 'Companyname_peugeot' has VIF > 10, it will be dropped and model will be rebuilt without it.

# %%
# Dropping 'Companyname_peugeot'
X_train_13 = X_train_12.drop(["Companyname_peugeot"], axis = 1)

# %%
# Rebuilding the model
# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_13)

# %%
# Running the linear model
lm = sm.OLS(y_train,X_train_lm).fit()

# %%
# Summary of linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.860
# Model:                            OLS   Adj. R-squared:                  0.852
# Method:                 Least Squares   F-statistic:                     118.0
# Date:                Mon, 29 Apr 2019   Prob (F-statistic):           2.41e-54
# Time:                        17:20:05   Log-Likelihood:                 157.28
# No. Observations:                 143   AIC:                            -298.6
# Df Residuals:                     135   BIC:                            -274.9
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  -0.1484      0.025     -5.865      0.000      -0.198      -0.098
# ...

# %%
# Dropping 'const'
X_train_14 = X_train_13.drop(["const"], axis = 1)

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_14
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#               Features   VIF
# 0           enginesize  2.77
# 1              peakrpm  2.44
# 4       fuelsystem_idi  1.36
# 2         enginetype_l  1.18
# 3     enginetype_rotor  1.17
# 5      Companyname_bmw  1.13
# 6  Companyname_porsche  1.08

# %% [markdown]
# Since 'enginetype_l' is insignificant (high p-value) in presence of other variables, it will be dropped and model will be rebuilt without it.

# %%
# Dropping 'enginetype_l'
X_train_14 = X_train_13.drop(["enginetype_l"], axis = 1)

# %%
# Rebuilding the model
# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_14)

# %%
# Running the linear model
lm = sm.OLS(y_train,X_train_lm).fit()

# %%
# Summary of linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.859
# Model:                            OLS   Adj. R-squared:                  0.853
# Method:                 Least Squares   F-statistic:                     138.0
# Date:                Mon, 29 Apr 2019   Prob (F-statistic):           2.61e-55
# Time:                        17:20:05   Log-Likelihood:                 156.98
# No. Observations:                 143   AIC:                            -300.0
# Df Residuals:                     136   BIC:                            -279.2
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  -0.1458      0.025     -5.825      0.000      -0.195      -0.096
# ...

# %%
# Dropping 'const'
X_train_15 = X_train_14.drop(["const"], axis = 1)

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_15
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#               Features   VIF
# 0           enginesize  2.76
# 1              peakrpm  2.43
# 3       fuelsystem_idi  1.23
# 2     enginetype_rotor  1.17
# 4      Companyname_bmw  1.13
# 5  Companyname_porsche  1.07

# %% [markdown]
# p-value and VIF of all the features are within limits and r-squared/ adjusted r-squared is constant as well for this model.
#
# We can proceed with residual analysis.

# %% [markdown]
# Residual analysis of TRAIN DATA:
# So, now to check if the error terms are also normally distributed, the histogram will be plotted of the error terms and see what it looks like.

# %%
y_train_price = lm.predict(X_train_lm)

# %%
# Importing the required libraries for plots.
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Plot the histogram of the error terms
fig = plt.figure()
sns.distplot((y_train - y_train_price), bins = 20)
fig.suptitle('Error Terms', fontsize = 20)                  # Plot heading 
plt.xlabel('Errors', fontsize = 20)                         # X-label
# Out:
# Text(0.5, 0, 'Errors')

# %% [markdown]
# MAKING PREDICTIONS

# %% [markdown]
# Applying the scaling on the test sets

# %%
num_vars = ['symboling', 'wheelbase', 'carlength', 'carwidth', 'carheight', 
            'curbweight', 'cylindernumber', 'enginesize', 'boreratio', 'stroke',
            'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price']

df_test[num_vars] = scaler.transform(df_test[num_vars])

# %% [markdown]
# Dividing into X_test and y_test

# %%
y_test = df_test.pop('price')
X_test = df_test

# %%
# Now let's use our model to make predictions.

# Creating X_test_new dataframe by dropping variables from X_test
X_test_new = X_test[X_train_15.columns]

# Adding a constant variable 
X_test_new = sm.add_constant(X_test_new)

# %%
# Making predictions
y_pred = lm.predict(X_test_new)

# %% [markdown]
# MODEL EVALUATION

# %%
# Plotting y_test and y_pred to understand the spread.
fig = plt.figure()
plt.scatter(y_test,y_pred)
fig.suptitle('y_test vs y_pred', fontsize=20)              # Plot heading 
plt.xlabel('y_test', fontsize=18)                          # X-label
plt.ylabel('y_pred', fontsize=16)                          # Y-label
# Out:
# Text(0, 0.5, 'y_pred')

# %% [markdown]
# TRAIN SET:
#
# R-squared score: 0.859
#
# Adjusted R-squared score: 0.853

# %% [markdown]
# Calculate the R-squared score on the test set:

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.8525529106092413

# %% [markdown]
# VARIABLES SIGNIFICANT IN PREDICTING THE PRICE OF A CAR:
# 1. enginesize
# 2. peakrpm
# 3. fuelsystem_idi
# 4. enginetype_rotor
# 5. Companyname_bmw
# 6. Companyname_porsche
#
# EQUATION OF THE BEST FITTED LINE IS:
#
# price = (1.1691 * enginesize) + (0.1320 * peakrpm) + (0.2137 * enginetype_rotor) +  (0.1171 * fuelsystem_idi) +  (0.2276 * Companyname_bmw) + (0.1885 * Companyname_porsche)
